# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36"
}
def scrape_jumia_monitors(page_num):
    url = f"https://www.jumia.com.eg/televisions/?page={page_num}"
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.content, "html.parser")

    products = soup.find_all("article", {"class": "prd _fb col c-prd"})

    product_data = []

    for product in products:
        try:
            name = product.find("h3", {"class": "name"}).text.strip()
        except:
            name = None

        try:
            price = product.find("div", {"class": "prc"}).text.strip()
        except:
            price = None

        try:
            rating = product.find("div", {"class": "rev"}).text.strip("()").strip()
        except:
            rating = None

        try:
            reviews = product.find("div", {"class": "rev"}).text.strip("()")
        except:
            reviews = None

        try:
            product_url = "https://www.jumia.com.eg" + product.find("a")["href"]
        except:
            product_url = None

        try:
            image_url = product.find("img")["data-src"]
        except:
            image_url = None

        brand = name.split()[0] if name else None

        product_data.append({
            "Product Name": name,
            "Price": price,
            "Rating": rating,
            "Number of Reviews": reviews,
            "Product URL": product_url,
            "Image URL": image_url,
            "Brand": brand
        })

    return product_data

# %%
all_products = []

for page in range(1, 4):  # scrape 3 pages
    print(f"Scraping page {page}...")
    data = scrape_jumia_monitors(page)
    all_products.extend(data)
    time.sleep(2)  # be polite to the server

print(f"Total products scraped: {len(all_products)}")
# Out:
# Scraping page 1...
# Scraping page 2...
# Scraping page 3...
# Total products scraped: 120

# %%
df = pd.DataFrame(all_products)

# %%
df.drop_duplicates()
df["Price"] = df["Price"].str.replace("EGP", "").str.replace(",", "").astype(float)
df
# Out:
#                                           Product Name    Price  \
# 0    LG 43LM6370PVA.AFU Series Full HD HDR Smart LE...  13299.0
# 1    Samsung ‎‎50 Inch Crystal UHD DU7000 4K Tizen ...  17299.0
# 2    Samsung ‎‎55 Inch Crystal UHD DU7000 4K Tizen ...  19299.0
# 3         Skyline 32-22A - 32-inch HD LED TV - Limited   3899.0
# 4                            ATA 32HON - 32-inch HD TV   4099.0
# ..                                                 ...      ...
# 115  LG Smart LED TV With Magic Remote Nanocell 55 ...  25499.0
# 116  Itel S32101BE Icast 32 Inch HD- Built-in Recei...   4700.0
# 117                     LG 50NANO776RA  50-Inch Screen  28637.0
# 118                 Samsung HD Smart TV 32" Inch T5300  10500.0
# 119  Samsung 65 Inch QLED 4K Smart TV - Titan Gray ...  42999.0
#
#                Rating Number of Reviews  \
# 0     4.9 out of 5(15   4.9 out of 5(15
# 1     4.2 out of 5(73   4.2 out of 5(73
# 2     4.3 out of 5(80   4.3 out of 5(80
# 3    3.9 out of 5(317  3.9 out of 5(317
# 4      4 out of 5(269    4 out of 5(269
# ..                ...               ...
# 115              None              None
# 116    3.5 out of 5(4    3.5 out of 5(4
# 117              None              None
# 118              None              None
# 119              None              None
#
#                                            Product URL  \
# 0    https://www.jumia.com.eg/customer/account/logi...
# 1    https://www.jumia.com.eg/customer/account/logi...
# 2    https://www.jumia.com.eg/customer/account/logi...
# 3    https://www.jumia.com.eg/customer/account/logi...
# 4    https://www.jumia.com.eg/customer/account/logi...
# ..                                                 ...
# 115  https://www.jumia.com.eg/customer/account/logi...
# 116  https://www.jumia.com.eg/customer/account/logi...
# 117  https://www.jumia.com.eg/customer/account/logi...
# 118  https://www.jumia.com.eg/customer/account/logi...
# 119  https://www.jumia.com.eg/customer/account/logi...
#
#                                              Image URL    Brand
# 0    https://eg.jumia.is/unsafe/fit-in/300x300/filt...       LG
# 1    https://eg.jumia.is/unsafe/fit-in/300x300/filt...  Samsung
# 2    https://eg.jumia.is/unsafe/fit-in/300x300/filt...  Samsung
# 3    https://eg.jumia.is/unsafe/fit-in/300x300/filt...  Skyline
# 4    https://eg.jumia.is/unsafe/fit-in/300x300/filt...      ATA
# ..                                                 ...      ...
# 115  https://eg.jumia.is/unsafe/fit-in/300x300/filt...       LG
# 116  https://eg.jumia.is/unsafe/fit-in/300x300/filt...     Itel
# 117  https://eg.jumia.is/unsafe/fit-in/300x300/filt...       LG
# 118  https://eg.jumia.is/unsafe/fit-in/300x300/filt...  Samsung
# 119  https://eg.jumia.is/unsafe/fit-in/300x300/filt...  Samsung
#
# [120 rows x 7 columns]

# %%
df.to_csv("jumia_monitors.csv", index=False)
